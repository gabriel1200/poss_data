# %%
import pandas as pd
def get_team_dict():
    """Returns a dictionary mapping team abbreviations to team IDs."""
    return {
        'ATL': '1610612737', 'BKN': '1610612751', 'BOS': '1610612738', 'CHA': '1610612766',
        'CHI': '1610612741', 'CLE': '1610612739', 'DAL': '1610612742', 'DEN': '1610612743',
        'DET': '1610612765', 'GSW': '1610612744', 'HOU': '1610612745', 'IND': '1610612754',
        'LAC': '1610612746', 'LAL': '1610612747', 'MEM': '1610612763', 'MIA': '1610612748',
        'MIL': '1610612749', 'MIN': '1610612750', 'NOP': '1610612740', 'NYK': '1610612752',
        'OKC': '1610612760', 'ORL': '1610612753', 'PHI': '1610612755', 'PHX': '1610612756',
        'POR': '1610612757', 'SAC': '1610612758', 'SAS': '1610612759', 'TOR': '1610612761',
        'UTA': '1610612762', 'WAS': '1610612764'
    }
team_dict=get_team_dict()
frames = []
year=2025
for key,value in team_dict.items():
    df= pd.read_csv(f"{year}/{key}_{year}_clips_with_players.csv")
    frames.append(df)
data=pd.concat(frames)
print(len(data))
data['players_on'].str.split('|')
data['length']=data['players_on'].str.split('|').str.len()
print(100* data['length'].value_counts()/len(data))

data['length2']=data['opp_players_on'].str.split('|').str.len()
print(100* data['length2'].value_counts()/len(data))

temp=frames[0]
temp.head(20)[['DESCRIPTION','URL','GAMEDATE','OPPONENT','team','PERIOD','start_seconds']]
# Out:
# 310912
# 5.0    99.680939
# 4.0     0.097134
# 3.0     0.062719
# 6.0     0.061432
# 7.0     0.048567
# 2.0     0.027339
# 8.0     0.010614
# 1.0     0.005468
# Name: length, dtype: float64
# 5.0    99.679974
# 4.0     0.101315
# 3.0     0.057251
# 6.0     0.056929
# 7.0     0.045029
# 2.0     0.032163
# 8.0     0.015438
# 1.0     0.006433
# Name: length2, dtype: float64
#                                           DESCRIPTION  \
# 0                     MISS Brown 13' Pullup Jump Shot
# 1                                     CELTICS Rebound
# 2                   Daniels P.FOUL (P3.T4) (R.Acosta)
# 3   Holiday Out of Bounds - Bad Pass Turnover Turn...
# 4                        MISS Tatum 24' 3PT Jump Shot
# 5                      Johnson REBOUND (Off:3 Def:10)
# 6    Brown 16' Fadeaway Jumper (37 PTS) (White 5 AST)
# 7             Brown 27' 3PT Pullup Jump Shot (35 PTS)
# 8      White 25' 3PT Jump Shot (31 PTS) (Tatum 8 AST)
# 9                   Okongwu S.FOUL (P4.T3) (R.Acosta)
# 10                       MISS Brown Free Throw 1 of 2
# 11                                    CELTICS Rebound
# 12                       MISS Brown Free Throw 2 of 2
# 13                      Johnson REBOUND (Off:2 Def:9)
# 14                Daniels S.FOUL (P2.T2) (C.Kirkland)
# 15                       MISS Brown Free Throw 1 of 2
# 16                                    CELTICS Rebound
# 17                   Brown Free Throw 2 of 2 (32 PTS)
# 18  Tatum Lost Ball Turnover (P5.T19): Johnson STE...
# 19  Brown 24' 3PT Pullup Jump Shot (31 PTS) (Holid...
#
#                                                   URL    GAMEDATE OPPONENT  \
# 0   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 1                                                 NaN  2024-11-12      ATL
# 2                                                 NaN  2024-11-12      ATL
# 3   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 4   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 5   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 6   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 7   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 8   https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 9                                                 NaN  2024-11-12      ATL
# 10                                                NaN  2024-11-12      ATL
# 11                                                NaN  2024-11-12      ATL
# 12                                                NaN  2024-11-12      ATL
# 13  https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 14                                                NaN  2024-11-12      ATL
# 15                                                NaN  2024-11-12      ATL
# 16                                                NaN  2024-11-12      ATL
# 17                                                NaN  2024-11-12      ATL
# 18  https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
# 19  https://videos.nba.com/nba/pbp/media/2024/11/1...  2024-11-12      ATL
#
#     PERIOD  start_seconds
# 0        4           2877
# 1        4           2877
# 2        4           2874
# 3        4           2874
# 4        4           2838
# 5        4           2838
# 6        4           2811
# 7        4           2781
# 8        4           2745
# 9        4           2706
# 10       4           2706
# 11       4           2706
# 12       4           2706
# 13       4           2706
# 14       4           2691
# 15       4           2691
# 16       4           2691
# 17       4           2691
# 18       4           2650
# 19       4           2613

# %%
import pandas as pd
import re

import pandas as pd
import re

def get_filtered_videos(seasons, team, players_on, players_off, offense_defense=False):
    frames = []
    for season in seasons:
        year = int(season.split('-')[0]) + 1
        base_url = f'https://raw.githubusercontent.com/gabriel1200/poss_data/refs/heads/master/{year}/{team}_{year}_clips_with_players.csv'
        frame = pd.read_csv(base_url)
        frames.append(frame)
    
    data = pd.concat(frames)
    data.sort_values(by=['GAMEDATE','start_seconds'],inplace=True)
    data = data[data.URL.isna() == False]
    data.drop_duplicates(subset=['URL'],inplace=True)
    
    
    # Create regex patterns with word boundaries to prevent partial matches
    players_on_pattern = '|'.join([rf'\b{re.escape(p)}\b' for p in players_on]) if players_on else ''
    players_off_pattern = '|'.join([rf'\b{re.escape(p)}\b' for p in players_off]) if players_off else ''
    
    # Filter rows with any players_on present
    if players_on:
        data = data[data.players_on.str.contains(players_on_pattern, regex=True, na=False)]
    
    # Exclude rows with any players_off present
    if players_off:
        data = data[~data.players_off.str.contains(players_off_pattern, regex=True, na=False)]
    
    return data[['DESCRIPTION','URL','GAMEDATE','OPPONENT','PERIOD','start_seconds']]

   
videos=get_filtered_videos(['2024-2025'],'LAL',['2544'],[])
videos
# Out:
#                                             DESCRIPTION  \
# 947                      MISS Edwards 27' 3PT Jump Shot
# 948                      L. James REBOUND (Off:0 Def:1)
# 946   McDaniels 4' Driving Finger Roll Layup (2 PTS)...
# 944    Edwards 24' 3PT Jump Shot (3 PTS) (Randle 2 AST)
# 942   L. James BLOCK (1 BLK): MISS McDaniels 4' Runn...
# ...                                                 ...
# 8702                  Podziemski Tip Layup Shot (8 PTS)
# 8699            Curry 29' 3PT Pullup Jump Shot (35 PTS)
# 8693                        MISS Hield 3' Driving Layup
# 8692  Curry 3' Cutting Layup Shot (37 PTS) (Green 4 ...
# 8690                       MISS Curry 28' 3PT Jump Shot
#
#                                                     URL    GAMEDATE OPPONENT  \
# 947   https://videos.nba.com/nba/pbp/media/2024/10/2...  2024-10-22      LAL
# 948   https://videos.nba.com/nba/pbp/media/2024/10/2...  2024-10-22      LAL
# 946   https://videos.nba.com/nba/pbp/media/2024/10/2...  2024-10-22      LAL
# 944   https://videos.nba.com/nba/pbp/media/2024/10/2...  2024-10-22      LAL
# 942   https://videos.nba.com/nba/pbp/media/2024/10/2...  2024-10-22      LAL
# ...                                                 ...         ...      ...
# 8702  https://videos.nba.com/nba/pbp/media/2025/02/0...  2025-02-06      LAL
# 8699  https://videos.nba.com/nba/pbp/media/2025/02/0...  2025-02-06      LAL
# 8693  https://videos.nba.com/nba/pbp/media/2025/02/0...  2025-02-06      LAL
# 8692  https://videos.nba.com/nba/pbp/media/2025/02/0...  2025-02-06      LAL
# 8690  https://videos.nba.com/nba/pbp/media/2025/02/0...  2025-02-06      LAL
#
#       PERIOD  start_seconds
# 947        1              0
# 948        1              0
# 946        1             42
# 944        1             97
# 942        1            147
# ...      ...            ...
# 8702       4           2782
# 8699       4           2812
# 8693       4           2832
# 8692       4           2853
# 8690       4           2862
#
# [4796 rows x 6 columns]
