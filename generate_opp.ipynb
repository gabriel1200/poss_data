# %%
import pandas as pd
import glob
import os
import sys
def process_flip_files(ps = False):

    year_dirs = [d for d in os.listdir() if d.isdigit()]
    
    # Process each year directory
    for year in year_dirs:
        all_dfs = []
        # Find all CSV files in the year directory
        files = glob.glob(os.path.join(year, "*_clips_with_players.csv"))

        if ps:
            files = [f for f in files if f"{year}ps" in str(f)]
            trail = 'ps'
        else:
            files = [f for f in files if f"{year}ps"  not in str(f)]
            trail = ''
        files = [file for file in files if 'v' not in str(file)]
        print(len(files))
   
        
        # Read each file and append to our list
        for file in files:
            try:
                df = pd.read_csv(file)
                all_dfs.append(df)
            except Exception as e:
                print(f"Error reading {file}: {e}")
    
    # Combine all DataFrames
        if not all_dfs:
            print("No data files found!")
            return
            
        all_data = pd.concat(all_dfs, ignore_index=True)
        
        # Get unique opponents
        opponents = all_data['OPPONENT'].unique()
        
        # Create 'processed' directory if it doesn't exist
        if not os.path.exists('processed'):
            os.makedirs('processed')
        
        # Create a new CSV for each opponent
        for opponent in opponents:
            # Filter data for this opponent
            opponent_data = all_data[all_data['OPPONENT'] == opponent]

            opponent_data = opponent_data.rename(columns={'players_on': 'opp_players_on', 'opp_players_on': 'players_on'})

            # Create filename - replace any spaces or special characters
            filename = f"{year}/{opponent}_vs_{year}{trail}_clips_with_players.csv"
            
            # Save to CSV
            opponent_data.to_csv(filename, index=False)
            print(f"Created {filename}")

if __name__ == "__main__":
    process_flip_files(ps=True)
# Out:
# Created 2015/HOU_vs_2015ps_clips_with_players.csv
# Created 2015/CLE_vs_2015ps_clips_with_players.csv
# Created 2015/DAL_vs_2015ps_clips_with_players.csv
# Created 2015/LAC_vs_2015ps_clips_with_players.csv
# Created 2015/GSW_vs_2015ps_clips_with_players.csv
# Created 2015/TOR_vs_2015ps_clips_with_players.csv
# Created 2015/ATL_vs_2015ps_clips_with_players.csv
# Created 2015/BOS_vs_2015ps_clips_with_players.csv
# Created 2015/SAS_vs_2015ps_clips_with_players.csv
# Created 2015/NOP_vs_2015ps_clips_with_players.csv
# Created 2015/POR_vs_2015ps_clips_with_players.csv
# Created 2015/CHI_vs_2015ps_clips_with_players.csv
# Created 2015/BKN_vs_2015ps_clips_with_players.csv
# Created 2015/WAS_vs_2015ps_clips_with_players.csv
# Created 2015/MIL_vs_2015ps_clips_with_players.csv
# Created 2015/MEM_vs_2015ps_clips_with_players.csv
# Created 2022/DAL_vs_2022ps_clips_with_players.csv
# Created 2022/GSW_vs_2022ps_clips_with_players.csv
# Created 2022/PHI_vs_2022ps_clips_with_players.csv
# Created 2022/PHX_vs_2022ps_clips_with_players.csv
# Created 2022/MIA_vs_2022ps_clips_with_players.csv
# Created 2022/MIN_vs_2022ps_clips_with_players.csv
# Created 2022/DEN_vs_2022ps_clips_with_players.csv
# Created 2022/MEM_vs_2022ps_clips_with_players.csv
# Created 2022/BOS_vs_2022ps_clips_with_players.csv
# Created 2022/TOR_vs_2022ps_clips_with_players.csv
# Created 2022/ATL_vs_2022ps_clips_with_players.csv
# Created 2022/CHI_vs_2022ps_clips_with_players.csv
# Created 2022/NOP_vs_2022ps_clips_with_players.csv
# Created 2022/MIL_vs_2022ps_clips_with_players.csv
# Created 2022/UTA_vs_2022ps_clips_with_players.csv
# Created 2022/BKN_vs_2022ps_clips_with_players.csv
# Created 2021/WAS_vs_2021ps_clips_with_players.csv
# Created 2021/ATL_vs_2021ps_clips_with_players.csv
# Created 2021/POR_vs_2021ps_clips_with_players.csv
# Created 2021/MEM_vs_2021ps_clips_with_players.csv
# Created 2021/LAC_vs_2021ps_clips_with_players.csv
# Created 2021/BOS_vs_2021ps_clips_with_players.csv
# Created 2021/MIL_vs_2021ps_clips_with_players.csv
# Created 2021/PHI_vs_2021ps_clips_with_players.csv
# Created 2021/PHX_vs_2021ps_clips_with_players.csv
# Created 2021/DAL_vs_2021ps_clips_with_players.csv
# Created 2021/UTA_vs_2021ps_clips_with_players.csv
# Created 2021/NYK_vs_2021ps_clips_with_players.csv
# Created 2021/BKN_vs_2021ps_clips_with_players.csv
# Created 2021/MIA_vs_2021ps_clips_with_players.csv
# Created 2021/DEN_vs_2021ps_clips_with_players.csv
# Created 2021/LAL_vs_2021ps_clips_with_players.csv
# Created 2018/POR_vs_2018ps_clips_with_players.csv
# Created 2018/GSW_vs_2018ps_clips_with_players.csv
# Created 2018/CLE_vs_2018ps_clips_with_players.csv
# Created 2018/MIA_vs_2018ps_clips_with_players.csv
# Created 2018/BOS_vs_2018ps_clips_with_players.csv
# Created 2018/IND_vs_2018ps_clips_with_players.csv
# Created 2018/NOP_vs_2018ps_clips_with_players.csv
# Created 2018/HOU_vs_2018ps_clips_with_players.csv
# Created 2018/SAS_vs_2018ps_clips_with_players.csv
# Created 2018/PHI_vs_2018ps_clips_with_players.csv
# Created 2018/TOR_vs_2018ps_clips_with_players.csv
# Created 2018/MIL_vs_2018ps_clips_with_players.csv
# Created 2018/WAS_vs_2018ps_clips_with_players.csv
# Created 2018/OKC_vs_2018ps_clips_with_players.csv
# Created 2018/MIN_vs_2018ps_clips_with_players.csv
# Created 2018/UTA_vs_2018ps_clips_with_players.csv
# Created 2016/DAL_vs_2016ps_clips_with_players.csv
# Created 2016/SAS_vs_2016ps_clips_with_players.csv
# Created 2016/GSW_vs_2016ps_clips_with_players.csv
# Created 2016/ATL_vs_2016ps_clips_with_players.csv
# Created 2016/TOR_vs_2016ps_clips_with_players.csv
# Created 2016/IND_vs_2016ps_clips_with_players.csv
# Created 2016/POR_vs_2016ps_clips_with_players.csv
# Created 2016/LAC_vs_2016ps_clips_with_players.csv
# Created 2016/BOS_vs_2016ps_clips_with_players.csv
# Created 2016/CLE_vs_2016ps_clips_with_players.csv
# Created 2016/CHA_vs_2016ps_clips_with_players.csv
# Created 2016/HOU_vs_2016ps_clips_with_players.csv
# Created 2016/OKC_vs_2016ps_clips_with_players.csv
# Created 2016/MIA_vs_2016ps_clips_with_players.csv
# Created 2016/MEM_vs_2016ps_clips_with_players.csv
# Created 2016/DET_vs_2016ps_clips_with_players.csv
# Created 2023/PHX_vs_2023ps_clips_with_players.csv
# Created 2023/GSW_vs_2023ps_clips_with_players.csv
# Created 2023/BKN_vs_2023ps_clips_with_players.csv
# Created 2023/PHI_vs_2023ps_clips_with_players.csv
# Created 2023/DEN_vs_2023ps_clips_with_players.csv
# Created 2023/BOS_vs_2023ps_clips_with_players.csv
# Created 2023/NYK_vs_2023ps_clips_with_players.csv
# Created 2023/MIN_vs_2023ps_clips_with_players.csv
# Created 2023/LAL_vs_2023ps_clips_with_players.csv
# Created 2023/MIA_vs_2023ps_clips_with_players.csv
# Created 2023/SAC_vs_2023ps_clips_with_players.csv
# Created 2023/MEM_vs_2023ps_clips_with_players.csv
# Created 2023/MIL_vs_2023ps_clips_with_players.csv
# Created 2023/ATL_vs_2023ps_clips_with_players.csv
# Created 2023/CLE_vs_2023ps_clips_with_players.csv
# Created 2023/LAC_vs_2023ps_clips_with_players.csv
# Created 2019/OKC_vs_2019ps_clips_with_players.csv
# Created 2019/BOS_vs_2019ps_clips_with_players.csv
# Created 2019/TOR_vs_2019ps_clips_with_players.csv
# Created 2019/IND_vs_2019ps_clips_with_players.csv
# Created 2019/MIL_vs_2019ps_clips_with_players.csv
# Created 2019/SAS_vs_2019ps_clips_with_players.csv
# Created 2019/BKN_vs_2019ps_clips_with_players.csv
# Created 2019/LAC_vs_2019ps_clips_with_players.csv
# Created 2019/HOU_vs_2019ps_clips_with_players.csv
# Created 2019/POR_vs_2019ps_clips_with_players.csv
# Created 2019/DEN_vs_2019ps_clips_with_players.csv
# Created 2019/GSW_vs_2019ps_clips_with_players.csv
# Created 2019/ORL_vs_2019ps_clips_with_players.csv
# Created 2019/PHI_vs_2019ps_clips_with_players.csv
# Created 2019/UTA_vs_2019ps_clips_with_players.csv
# Created 2019/DET_vs_2019ps_clips_with_players.csv
# Created 2020/TOR_vs_2020ps_clips_with_players.csv
# Created 2020/DAL_vs_2020ps_clips_with_players.csv
# Created 2020/DEN_vs_2020ps_clips_with_players.csv
# Created 2020/MIL_vs_2020ps_clips_with_players.csv
# Created 2020/PHI_vs_2020ps_clips_with_players.csv
# Created 2020/MIA_vs_2020ps_clips_with_players.csv
# Created 2020/LAL_vs_2020ps_clips_with_players.csv
# Created 2020/LAC_vs_2020ps_clips_with_players.csv
# Created 2020/POR_vs_2020ps_clips_with_players.csv
# Created 2020/HOU_vs_2020ps_clips_with_players.csv
# Created 2020/UTA_vs_2020ps_clips_with_players.csv
# Created 2020/BKN_vs_2020ps_clips_with_players.csv
# Created 2020/BOS_vs_2020ps_clips_with_players.csv
# Created 2020/OKC_vs_2020ps_clips_with_players.csv
# Created 2020/IND_vs_2020ps_clips_with_players.csv
# Created 2020/ORL_vs_2020ps_clips_with_players.csv
# Created 2017/HOU_vs_2017ps_clips_with_players.csv
# Created 2017/WAS_vs_2017ps_clips_with_players.csv
# Created 2017/ATL_vs_2017ps_clips_with_players.csv
# Created 2017/SAS_vs_2017ps_clips_with_players.csv
# Created 2017/BOS_vs_2017ps_clips_with_players.csv
# Created 2017/CHI_vs_2017ps_clips_with_players.csv
# Created 2017/MEM_vs_2017ps_clips_with_players.csv
# Created 2017/CLE_vs_2017ps_clips_with_players.csv
# Created 2017/POR_vs_2017ps_clips_with_players.csv
# Created 2017/UTA_vs_2017ps_clips_with_players.csv
# Created 2017/LAC_vs_2017ps_clips_with_players.csv
# Created 2017/GSW_vs_2017ps_clips_with_players.csv
# Created 2017/IND_vs_2017ps_clips_with_players.csv
# Created 2017/TOR_vs_2017ps_clips_with_players.csv
# Created 2017/OKC_vs_2017ps_clips_with_players.csv
# Created 2017/MIL_vs_2017ps_clips_with_players.csv
# No data files found!
