# %%
import pandas as pd
import numpy as np
import os
import logging
from datetime import datetime
import sys
from collections import defaultdict

import requests
import pandas as pd
import numpy as np
import json
import time

import os

def get_team_dict():
    """Returns a dictionary mapping team abbreviations to team IDs."""
    return {
        'ATL': '1610612737', 'BKN': '1610612751', 'BOS': '1610612738', 'CHA': '1610612766',
        'CHI': '1610612741', 'CLE': '1610612739', 'DAL': '1610612742', 'DEN': '1610612743',
        'DET': '1610612765', 'GSW': '1610612744', 'HOU': '1610612745', 'IND': '1610612754',
        'LAC': '1610612746', 'LAL': '1610612747', 'MEM': '1610612763', 'MIA': '1610612748',
        'MIL': '1610612749', 'MIN': '1610612750', 'NOP': '1610612740', 'NYK': '1610612752',
        'OKC': '1610612760', 'ORL': '1610612753', 'PHI': '1610612755', 'PHX': '1610612756',
        'POR': '1610612757', 'SAC': '1610612758', 'SAS': '1610612759', 'TOR': '1610612761',
        'UTA': '1610612762', 'WAS': '1610612764'
    }

def get_id_to_team_abbrev():
    """Returns a dictionary mapping team IDs to team abbreviations."""
    team_dict = get_team_dict()
    return {v: k for k, v in team_dict.items()}

def convert_time_to_seconds(period, time_str):
    """Convert period and MM:SS format to total game seconds"""
    minutes, seconds = map(int, time_str.split(':'))
    
    # Calculate total seconds for all previous periods
    if period <= 4:
        period_seconds = (period - 1) * 720  # 12-minute periods
    else:
        period_seconds = 4 * 720 + (period - 5) * 300  # 5-minute OT periods
    
    # Calculate time passed in current period (counting down)
    #print(period_seconds)
    current_period_length = 720 if period <= 4 else 300
    time_passed = current_period_length - (minutes * 60 + seconds)
    
    return period_seconds + time_passed

def main(year=2025):
    # Set up logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        filename='player_tracking_log.txt',
        filemode='w'
    )
    console = logging.StreamHandler()
    console.setLevel(logging.INFO)
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console.setFormatter(formatter)
    logging.getLogger('').addHandler(console)
    
    ogyear = year
    season = str(year-1)+'-'+str(year)[-2:]
    logging.info("Starting player tracking process")
    
    # Get team ID to abbreviation mapping
    id_to_abbrev = get_id_to_team_abbrev()
    
    # Load the full datasets
    logging.info("Loading rotation and clips data")
    try:
        rotations_df = pd.read_csv(f"{year}_rotations.csv")
        clips_dir = f"nba_possessions_data/{year}"
        clips_files = [f for f in os.listdir(clips_dir) if f.startswith(str(year)) and f.endswith(".csv")]

        if not clips_files:
            logging.error(f"No clip files found in {clips_dir} starting with {year}")
            return None

        clips_df_list = []
        for file in clips_files:
            try:
                file_path = os.path.join(clips_dir, file)
                clips_df_list.append(pd.read_csv(file_path))
                logging.info(f"Loaded clip file: {file}")
            except Exception as e:
                logging.error(f"Error loading clip file {file}: {str(e)}")
                continue  # Skip to the next file if there's an error

        if not clips_df_list:
            logging.error("No clip data loaded successfully.")
            return None

        clips_df = pd.concat(clips_df_list, ignore_index=True)         
        # Convert team IDs to strings
        rotations_df['TEAM_ID'] = rotations_df['TEAM_ID'].astype(str)
        clips_df['TEAM_ID'] = clips_df['TEAM_ID'].astype(str)
        
        # Process rotation times (vectorized)
        rotations_df['IN_TIME_SEC'] = rotations_df['IN_TIME_REAL'] / 10
        rotations_df['OUT_TIME_SEC'] = rotations_df['OUT_TIME_REAL'] / 10
        
        logging.info(f"Loaded {len(rotations_df)} rotation records and {len(clips_df)} clip records")
    except Exception as e:
        logging.error(f"Error loading data: {str(e)}")
        return None
    
    # Extract year from GameDate (vectorized)
    clips_df['Year'] = pd.to_datetime(clips_df['GAMEDATE']).dt.year
    
    # Add game_seconds columns (vectorized using apply)
    logging.info("Converting game times to seconds")
    clips_df['start_seconds'] = clips_df.apply(
        lambda row: convert_time_to_seconds(int(row['PERIOD']), row['STARTTIME']), axis=1
    )
    clips_df['end_seconds'] = clips_df.apply(
        lambda row: convert_time_to_seconds(int(row['PERIOD']), row['ENDTIME']), axis=1
    )
    clips_df['mid_seconds'] = (clips_df['start_seconds'] + clips_df['end_seconds']) / 2
    
    # Create output directory if it doesn't exist
    output_dir = str(year) # year of the season end
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        logging.info(f"Created output directory: {output_dir}")
    
    # Pre-process rotation data to create a more efficient lookup structure
    logging.info("Creating rotation lookup structure")
    rotation_lookup = {}
    
    # Group rotations by game_id and team_id
    for game_id in rotations_df['GAME_ID'].unique():
        game_rotations = rotations_df[rotations_df['GAME_ID'] == game_id]
        rotation_lookup[game_id] = {}
        
        for team_id in game_rotations['TEAM_ID'].unique():
            team_rotations = game_rotations[game_rotations['TEAM_ID'] == team_id]
            rotation_lookup[game_id][team_id] = []
            
            for _, player_row in team_rotations.iterrows():
                rotation_lookup[game_id][team_id].append({
                    'player_id': str(player_row['PERSON_ID']),
                    'in_time': player_row['IN_TIME_SEC'],
                    'out_time': player_row['OUT_TIME_SEC']
                })
    
    # Function to get players on court using the efficient lookup structure
    def get_players_on_court(team_id, time_sec, game_id):
        if game_id not in rotation_lookup or team_id not in rotation_lookup[game_id]:
            return []
        
        on_court = []
        for player_data in rotation_lookup[game_id][team_id]:
            if player_data['in_time'] <= time_sec < player_data['out_time']:
                on_court.append(player_data['player_id'])
        
        if len(on_court) != 5:
   
            logging.warning(f"Found {len(on_court)} players for team {team_id} at time {time_sec} in game {game_id}. Expected 5 players.")
            if len(on_court)>=5:
                    '''
                    for player_data in rotation_lookup[game_id][team_id]:
                        print(player_data)
                    sys.exit()       
                    '''
                    pass      
            
        return on_court
    
    # Process each team in parallel
    teams = clips_df['TEAM_ID'].unique()
    years = clips_df['Year'].unique()
    
    logging.info(f"Processing data for {len(teams)} teams across {len(years)} years")
    
    for team in teams:
        team_abbrev = id_to_abbrev.get(team, team)  # Get team abbreviation or use ID if not found
        team_clips = clips_df[clips_df['TEAM_ID'] == team]
        
        if len(team_clips) == 0:
            logging.info(f"No clips found for {team_abbrev}, skipping")
            continue
        
        logging.info(f"Processing {len(team_clips)} clips for {team_abbrev}")
        
        # Process players on court for all clips at once
        players_on_list = []
        opp_players_on_list = []
        
        # Group by game to minimize lookups
        for game_id, game_clips in team_clips.groupby('GAMEID'):
            if game_id not in rotation_lookup:
                logging.warning(f"Game {game_id} not found in rotation data")
                players_on_list.extend(["GAME_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["GAME_NOT_FOUND"] * len(game_clips))
                continue
            
            game_teams = list(rotation_lookup[game_id].keys())
            if len(game_teams) < 2:
                logging.warning(f"Not enough teams found for game {game_id}")
                players_on_list.extend(["TEAMS_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["TEAMS_NOT_FOUND"] * len(game_clips))
                continue
            
            # Determine the opponent's team ID
            opponent_team_id = None
            for t_id in game_teams:
                if t_id != team:
                    opponent_team_id = t_id
                    break
            
            if opponent_team_id is None:
                logging.warning(f"Opponent team not found for game {game_id}")
                players_on_list.extend(["OPP_TEAM_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["OPP_TEAM_NOT_FOUND"] * len(game_clips))
                continue
            
            for _, row in game_clips.iterrows():
                try:
                    mid_time = row['mid_seconds']
      
                        #sys.exit()
                    offensive_players = get_players_on_court(team, mid_time, game_id)
                    defensive_players = get_players_on_court(opponent_team_id, mid_time, game_id)
                    players_on_list.append('|'.join(offensive_players))
                    opp_players_on_list.append('|'.join(defensive_players))
                except Exception as e:
                    logging.error(f"Error processing possession: {str(e)}")
                    players_on_list.append("ERROR")
                    opp_players_on_list.append("ERROR")
        
        # Add players_on column
        team_clips['players_on'] = players_on_list
        team_clips['opp_players_on'] = opp_players_on_list
        team_clips['season'] = season
        
        # Save results using team abbreviation
        output_file = f"{output_dir}/{team_abbrev}_{ogyear}_clips_with_players.csv"
        team_clips.to_csv(output_file, index=False)
        
        # Log statistics
        error_count = team_clips[team_clips['players_on'].isin(['ERROR', 'GAME_NOT_FOUND', 'TEAMS_NOT_FOUND', 'OPP_TEAM_NOT_FOUND'])].shape[0]
        success_count = team_clips.shape[0] - error_count
        logging.info(f"Processed {team_clips.shape[0]} clips for {team_abbrev}. "
                     f"Success: {success_count} ({success_count/team_clips.shape[0]*100:.1f}%), "
                     f"Errors: {error_count} ({error_count/team_clips.shape[0]*100:.1f}%)")
    
    logging.info("Processing complete")
    return True

if __name__ == "__main__":
    start_time = datetime.now()
    logging.info(f"Script started at {start_time}")
    
    result = main(year=2014)
    
    end_time = datetime.now()
    execution_time = end_time - start_time
    logging.info(f"Script completed at {end_time}")
    logging.info(f"Total execution time: {execution_time}")
# Out:
# WARNING:root:Found 0 players for team 1610612756 at time 2864.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,048 - WARNING - Found 0 players for team 1610612756 at time 2864.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2864.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,051 - WARNING - Found 2 players for team 1610612742 at time 2864.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2828.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,052 - WARNING - Found 0 players for team 1610612756 at time 2828.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2828.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,054 - WARNING - Found 2 players for team 1610612742 at time 2828.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2798.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,055 - WARNING - Found 0 players for team 1610612756 at time 2798.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2798.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,057 - WARNING - Found 2 players for team 1610612742 at time 2798.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2775.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,059 - WARNING - Found 0 players for team 1610612756 at time 2775.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2775.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,062 - WARNING - Found 2 players for team 1610612742 at time 2775.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2775.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,063 - WARNING - Found 0 players for team 1610612756 at time 2775.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2775.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,065 - WARNING - Found 2 players for team 1610612742 at time 2775.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2747.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,069 - WARNING - Found 0 players for team 1610612756 at time 2747.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2747.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,070 - WARNING - Found 2 players for team 1610612742 at time 2747.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,072 - WARNING - Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,073 - WARNING - Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,075 - WARNING - Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,076 - WARNING - Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,078 - WARNING - Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,081 - WARNING - Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,083 - WARNING - Found 0 players for team 1610612756 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,084 - WARNING - Found 2 players for team 1610612742 at time 2721.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,085 - WARNING - Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,086 - WARNING - Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,087 - WARNING - Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,088 - WARNING - Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,090 - WARNING - Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,094 - WARNING - Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,095 - WARNING - Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,097 - WARNING - Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,098 - WARNING - Found 0 players for team 1610612756 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,099 - WARNING - Found 2 players for team 1610612742 at time 2700.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2668.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,100 - WARNING - Found 0 players for team 1610612756 at time 2668.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2668.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,101 - WARNING - Found 2 players for team 1610612742 at time 2668.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,102 - WARNING - Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,104 - WARNING - Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,106 - WARNING - Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,107 - WARNING - Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,109 - WARNING - Found 0 players for team 1610612756 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,110 - WARNING - Found 2 players for team 1610612742 at time 2633.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,112 - WARNING - Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,113 - WARNING - Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,114 - WARNING - Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,115 - WARNING - Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,116 - WARNING - Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,120 - WARNING - Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,121 - WARNING - Found 0 players for team 1610612756 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,123 - WARNING - Found 2 players for team 1610612742 at time 2599.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2564.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,124 - WARNING - Found 0 players for team 1610612756 at time 2564.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2564.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,129 - WARNING - Found 2 players for team 1610612742 at time 2564.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2564.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,131 - WARNING - Found 0 players for team 1610612756 at time 2564.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2564.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,132 - WARNING - Found 2 players for team 1610612742 at time 2564.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2536.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,133 - WARNING - Found 0 players for team 1610612756 at time 2536.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2536.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,135 - WARNING - Found 2 players for team 1610612742 at time 2536.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2536.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,136 - WARNING - Found 0 players for team 1610612756 at time 2536.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2536.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,137 - WARNING - Found 2 players for team 1610612742 at time 2536.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2500.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,139 - WARNING - Found 0 players for team 1610612756 at time 2500.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2500.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,141 - WARNING - Found 2 players for team 1610612742 at time 2500.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2477.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,142 - WARNING - Found 0 players for team 1610612756 at time 2477.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2477.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,144 - WARNING - Found 2 players for team 1610612742 at time 2477.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,146 - WARNING - Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,147 - WARNING - Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,149 - WARNING - Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,150 - WARNING - Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,154 - WARNING - Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,155 - WARNING - Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,157 - WARNING - Found 0 players for team 1610612756 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,158 - WARNING - Found 2 players for team 1610612742 at time 2445.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2393.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,160 - WARNING - Found 0 players for team 1610612756 at time 2393.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2393.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,161 - WARNING - Found 1 players for team 1610612742 at time 2393.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2393.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,162 - WARNING - Found 0 players for team 1610612756 at time 2393.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2393.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,164 - WARNING - Found 1 players for team 1610612742 at time 2393.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2359.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,165 - WARNING - Found 0 players for team 1610612756 at time 2359.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2359.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,166 - WARNING - Found 1 players for team 1610612742 at time 2359.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,167 - WARNING - Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,169 - WARNING - Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,171 - WARNING - Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,180 - WARNING - Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,181 - WARNING - Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,183 - WARNING - Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,184 - WARNING - Found 0 players for team 1610612756 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,186 - WARNING - Found 1 players for team 1610612742 at time 2333.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,187 - WARNING - Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,190 - WARNING - Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,192 - WARNING - Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,193 - WARNING - Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,195 - WARNING - Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,197 - WARNING - Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,199 - WARNING - Found 0 players for team 1610612756 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,200 - WARNING - Found 1 players for team 1610612742 at time 2316.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2283.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,202 - WARNING - Found 0 players for team 1610612756 at time 2283.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2283.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,204 - WARNING - Found 1 players for team 1610612742 at time 2283.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,205 - WARNING - Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,208 - WARNING - Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,210 - WARNING - Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,212 - WARNING - Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,214 - WARNING - Found 0 players for team 1610612756 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,215 - WARNING - Found 1 players for team 1610612742 at time 2254.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,216 - WARNING - Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,217 - WARNING - Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,219 - WARNING - Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,220 - WARNING - Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,221 - WARNING - Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,223 - WARNING - Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,227 - WARNING - Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,228 - WARNING - Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,230 - WARNING - Found 0 players for team 1610612756 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,231 - WARNING - Found 1 players for team 1610612742 at time 2214.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,232 - WARNING - Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,233 - WARNING - Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,234 - WARNING - Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,237 - WARNING - Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,239 - WARNING - Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,243 - WARNING - Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,245 - WARNING - Found 0 players for team 1610612756 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,246 - WARNING - Found 1 players for team 1610612742 at time 2184.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,248 - WARNING - Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,249 - WARNING - Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,251 - WARNING - Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,253 - WARNING - Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,254 - WARNING - Found 0 players for team 1610612756 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,255 - WARNING - Found 2 players for team 1610612742 at time 2157.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,257 - WARNING - Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,258 - WARNING - Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,262 - WARNING - Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,264 - WARNING - Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,265 - WARNING - Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,266 - WARNING - Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,268 - WARNING - Found 0 players for team 1610612756 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,271 - WARNING - Found 2 players for team 1610612742 at time 2125.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,272 - WARNING - Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,273 - WARNING - Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,275 - WARNING - Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,277 - WARNING - Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,279 - WARNING - Found 0 players for team 1610612756 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,280 - WARNING - Found 2 players for team 1610612742 at time 2099.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2067.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,281 - WARNING - Found 0 players for team 1610612756 at time 2067.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2067.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,282 - WARNING - Found 2 players for team 1610612742 at time 2067.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2067.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,284 - WARNING - Found 0 players for team 1610612756 at time 2067.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2067.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,285 - WARNING - Found 2 players for team 1610612742 at time 2067.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,286 - WARNING - Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,286 - WARNING - Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,291 - WARNING - Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,292 - WARNING - Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,293 - WARNING - Found 0 players for team 1610612756 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,296 - WARNING - Found 2 players for team 1610612742 at time 2049.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2029.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,297 - WARNING - Found 0 players for team 1610612756 at time 2029.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 2029.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,298 - WARNING - Found 3 players for team 1610612742 at time 2029.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2029.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,299 - WARNING - Found 0 players for team 1610612756 at time 2029.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 2029.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,302 - WARNING - Found 3 players for team 1610612742 at time 2029.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 2000.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,303 - WARNING - Found 0 players for team 1610612756 at time 2000.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 2000.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,305 - WARNING - Found 3 players for team 1610612742 at time 2000.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,306 - WARNING - Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,307 - WARNING - Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,309 - WARNING - Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,310 - WARNING - Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,311 - WARNING - Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,312 - WARNING - Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,314 - WARNING - Found 0 players for team 1610612756 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,315 - WARNING - Found 3 players for team 1610612742 at time 1971.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,316 - WARNING - Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,317 - WARNING - Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,318 - WARNING - Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,320 - WARNING - Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,321 - WARNING - Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,322 - WARNING - Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,323 - WARNING - Found 0 players for team 1610612756 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,324 - WARNING - Found 3 players for team 1610612742 at time 1934.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,332 - WARNING - Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,333 - WARNING - Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,335 - WARNING - Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,337 - WARNING - Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,338 - WARNING - Found 0 players for team 1610612756 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,340 - WARNING - Found 3 players for team 1610612742 at time 1892.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1866.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,342 - WARNING - Found 0 players for team 1610612756 at time 1866.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1866.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,343 - WARNING - Found 3 players for team 1610612742 at time 1866.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,345 - WARNING - Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,346 - WARNING - Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,349 - WARNING - Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,350 - WARNING - Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,351 - WARNING - Found 0 players for team 1610612756 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,352 - WARNING - Found 3 players for team 1610612742 at time 1820.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1800.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,354 - WARNING - Found 0 players for team 1610612756 at time 1800.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1800.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,355 - WARNING - Found 3 players for team 1610612742 at time 1800.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,358 - WARNING - Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,359 - WARNING - Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,361 - WARNING - Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,362 - WARNING - Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,364 - WARNING - Found 0 players for team 1610612756 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,366 - WARNING - Found 3 players for team 1610612742 at time 1764.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1732.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,369 - WARNING - Found 0 players for team 1610612756 at time 1732.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1732.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,371 - WARNING - Found 3 players for team 1610612742 at time 1732.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1691.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,372 - WARNING - Found 0 players for team 1610612756 at time 1691.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1691.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,374 - WARNING - Found 3 players for team 1610612742 at time 1691.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1691.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,377 - WARNING - Found 0 players for team 1610612756 at time 1691.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1691.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,378 - WARNING - Found 3 players for team 1610612742 at time 1691.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,382 - WARNING - Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,384 - WARNING - Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,386 - WARNING - Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,388 - WARNING - Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,390 - WARNING - Found 0 players for team 1610612756 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,391 - WARNING - Found 3 players for team 1610612742 at time 1666.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1630.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,393 - WARNING - Found 0 players for team 1610612756 at time 1630.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1630.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,394 - WARNING - Found 3 players for team 1610612742 at time 1630.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1599.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,395 - WARNING - Found 0 players for team 1610612756 at time 1599.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1599.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,397 - WARNING - Found 3 players for team 1610612742 at time 1599.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,398 - WARNING - Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,399 - WARNING - Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,401 - WARNING - Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,402 - WARNING - Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,404 - WARNING - Found 0 players for team 1610612756 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,405 - WARNING - Found 3 players for team 1610612742 at time 1572.0 in game 21800613. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612756 at time 1542.5 in game 21800613. Expected 5 players.
# 2025-02-22 02:27:07,406 - WARNING - Found 0 players for team 1610612756 at time 1542.5 in game 21800613. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612742 at time 1542.5 in game 21800613. Expected 5 players.
# ...
# WARNING:root:Found 1 players for team 1610612749 at time 481.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,671 - WARNING - Found 1 players for team 1610612749 at time 481.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 447.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,672 - WARNING - Found 1 players for team 1610612748 at time 447.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 447.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,679 - WARNING - Found 1 players for team 1610612749 at time 447.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 426.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,681 - WARNING - Found 1 players for team 1610612748 at time 426.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 426.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,682 - WARNING - Found 1 players for team 1610612749 at time 426.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 426.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,685 - WARNING - Found 1 players for team 1610612748 at time 426.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 426.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,687 - WARNING - Found 1 players for team 1610612749 at time 426.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 393.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,689 - WARNING - Found 0 players for team 1610612748 at time 393.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 393.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,691 - WARNING - Found 0 players for team 1610612749 at time 393.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 366.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,695 - WARNING - Found 0 players for team 1610612748 at time 366.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 366.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,697 - WARNING - Found 0 players for team 1610612749 at time 366.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 366.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,699 - WARNING - Found 0 players for team 1610612748 at time 366.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 366.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,700 - WARNING - Found 0 players for team 1610612749 at time 366.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 340.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,702 - WARNING - Found 0 players for team 1610612748 at time 340.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 340.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,704 - WARNING - Found 0 players for team 1610612749 at time 340.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 340.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,706 - WARNING - Found 0 players for team 1610612748 at time 340.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 340.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,707 - WARNING - Found 0 players for team 1610612749 at time 340.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 317.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,709 - WARNING - Found 0 players for team 1610612748 at time 317.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 317.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,711 - WARNING - Found 0 players for team 1610612749 at time 317.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 317.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,713 - WARNING - Found 0 players for team 1610612748 at time 317.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 317.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,714 - WARNING - Found 0 players for team 1610612749 at time 317.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 300.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,716 - WARNING - Found 0 players for team 1610612748 at time 300.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 300.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,717 - WARNING - Found 0 players for team 1610612749 at time 300.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 280.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,719 - WARNING - Found 0 players for team 1610612748 at time 280.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 280.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,729 - WARNING - Found 0 players for team 1610612749 at time 280.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 280.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,731 - WARNING - Found 0 players for team 1610612748 at time 280.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 280.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,732 - WARNING - Found 0 players for team 1610612749 at time 280.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 260.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,733 - WARNING - Found 0 players for team 1610612748 at time 260.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 260.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,734 - WARNING - Found 0 players for team 1610612749 at time 260.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 260.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,736 - WARNING - Found 0 players for team 1610612748 at time 260.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612749 at time 260.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,737 - WARNING - Found 0 players for team 1610612749 at time 260.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 225.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,738 - WARNING - Found 0 players for team 1610612748 at time 225.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 225.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,739 - WARNING - Found 1 players for team 1610612749 at time 225.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 204.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,741 - WARNING - Found 0 players for team 1610612748 at time 204.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 204.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,742 - WARNING - Found 1 players for team 1610612749 at time 204.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 175.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,744 - WARNING - Found 0 players for team 1610612748 at time 175.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 175.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,746 - WARNING - Found 1 players for team 1610612749 at time 175.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 175.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,748 - WARNING - Found 0 players for team 1610612748 at time 175.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 175.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,749 - WARNING - Found 1 players for team 1610612749 at time 175.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 148.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,751 - WARNING - Found 0 players for team 1610612748 at time 148.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 148.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,752 - WARNING - Found 1 players for team 1610612749 at time 148.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 148.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,754 - WARNING - Found 0 players for team 1610612748 at time 148.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 148.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,756 - WARNING - Found 1 players for team 1610612749 at time 148.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 120.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,758 - WARNING - Found 0 players for team 1610612748 at time 120.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 120.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,761 - WARNING - Found 1 players for team 1610612749 at time 120.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 120.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,763 - WARNING - Found 0 players for team 1610612748 at time 120.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 120.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,767 - WARNING - Found 1 players for team 1610612749 at time 120.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 96.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,769 - WARNING - Found 0 players for team 1610612748 at time 96.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 96.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,771 - WARNING - Found 1 players for team 1610612749 at time 96.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 96.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,773 - WARNING - Found 0 players for team 1610612748 at time 96.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 96.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,775 - WARNING - Found 1 players for team 1610612749 at time 96.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 73.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,777 - WARNING - Found 0 players for team 1610612748 at time 73.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 73.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,778 - WARNING - Found 1 players for team 1610612749 at time 73.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 73.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,780 - WARNING - Found 0 players for team 1610612748 at time 73.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 73.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,782 - WARNING - Found 1 players for team 1610612749 at time 73.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 42.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,784 - WARNING - Found 0 players for team 1610612748 at time 42.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 42.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,790 - WARNING - Found 1 players for team 1610612749 at time 42.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 42.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,791 - WARNING - Found 0 players for team 1610612748 at time 42.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 42.5 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,792 - WARNING - Found 1 players for team 1610612749 at time 42.5 in game 21800482. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612748 at time 9.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,794 - WARNING - Found 0 players for team 1610612748 at time 9.0 in game 21800482. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612749 at time 9.0 in game 21800482. Expected 5 players.
# 2025-02-22 02:27:46,795 - WARNING - Found 1 players for team 1610612749 at time 9.0 in game 21800482. Expected 5 players.
# /tmp/ipykernel_16167/3941612868.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_16167/3941612868.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_16167/3941612868.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
# /tmp/ipykernel_16167/3941612868.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_16167/3941612868.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_16167/3941612868.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
