# %%
import pandas as pd
import numpy as np
import os
import logging
from datetime import datetime
import sys
from collections import defaultdict

import requests
import pandas as pd
import numpy as np
import json
import time

import os

def get_team_dict():
    """Returns a dictionary mapping team abbreviations to team IDs."""
    return {
        'ATL': '1610612737', 'BKN': '1610612751', 'BOS': '1610612738', 'CHA': '1610612766',
        'CHI': '1610612741', 'CLE': '1610612739', 'DAL': '1610612742', 'DEN': '1610612743',
        'DET': '1610612765', 'GSW': '1610612744', 'HOU': '1610612745', 'IND': '1610612754',
        'LAC': '1610612746', 'LAL': '1610612747', 'MEM': '1610612763', 'MIA': '1610612748',
        'MIL': '1610612749', 'MIN': '1610612750', 'NOP': '1610612740', 'NYK': '1610612752',
        'OKC': '1610612760', 'ORL': '1610612753', 'PHI': '1610612755', 'PHX': '1610612756',
        'POR': '1610612757', 'SAC': '1610612758', 'SAS': '1610612759', 'TOR': '1610612761',
        'UTA': '1610612762', 'WAS': '1610612764'
    }

def get_id_to_team_abbrev():
    """Returns a dictionary mapping team IDs to team abbreviations."""
    team_dict = get_team_dict()
    return {v: k for k, v in team_dict.items()}

def convert_time_to_seconds(period, time_str):
    """Convert period and MM:SS format to total game seconds"""
    minutes, seconds = map(int, time_str.split(':'))
    
    # Calculate total seconds for all previous periods
    if period <= 4:
        period_seconds = (period - 1) * 720  # 12-minute periods
    else:
        period_seconds = 4 * 720 + (period - 5) * 300  # 5-minute OT periods
    
    # Calculate time passed in current period (counting down)
    #print(period_seconds)
    current_period_length = 720 if period <= 4 else 300
    time_passed = current_period_length - (minutes * 60 + seconds)
    
    return period_seconds + time_passed

def main(year=2025):
    # Set up logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        filename='player_tracking_log.txt',
        filemode='w'
    )
    console = logging.StreamHandler()
    console.setLevel(logging.INFO)
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console.setFormatter(formatter)
    logging.getLogger('').addHandler(console)
    
    ogyear = year
    season = str(year-1)+'-'+str(year)[-2:]
    logging.info("Starting player tracking process")
    
    # Get team ID to abbreviation mapping
    id_to_abbrev = get_id_to_team_abbrev()
    
    # Load the full datasets
    logging.info("Loading rotation and clips data")
    try:
        rotations_df = pd.read_csv(f"{year}_rotations.csv")
        clips_dir = f"nba_possessions_data/{year}"
        clips_files = [f for f in os.listdir(clips_dir) if f.startswith(str(year)) and f.endswith(".csv")]

        if not clips_files:
            logging.error(f"No clip files found in {clips_dir} starting with {year}")
            return None

        clips_df_list = []
        for file in clips_files:
            try:
                file_path = os.path.join(clips_dir, file)
                clips_df_list.append(pd.read_csv(file_path))
                logging.info(f"Loaded clip file: {file}")
            except Exception as e:
                logging.error(f"Error loading clip file {file}: {str(e)}")
                continue  # Skip to the next file if there's an error

        if not clips_df_list:
            logging.error("No clip data loaded successfully.")
            return None

        clips_df = pd.concat(clips_df_list, ignore_index=True)         
        # Convert team IDs to strings
        rotations_df['TEAM_ID'] = rotations_df['TEAM_ID'].astype(str)
        clips_df['TEAM_ID'] = clips_df['TEAM_ID'].astype(str)
        
        # Process rotation times (vectorized)
        rotations_df['IN_TIME_SEC'] = rotations_df['IN_TIME_REAL'] / 10
        rotations_df['OUT_TIME_SEC'] = rotations_df['OUT_TIME_REAL'] / 10
        
        logging.info(f"Loaded {len(rotations_df)} rotation records and {len(clips_df)} clip records")
    except Exception as e:
        logging.error(f"Error loading data: {str(e)}")
        return None
    
    # Extract year from GameDate (vectorized)
    clips_df['Year'] = pd.to_datetime(clips_df['GAMEDATE']).dt.year
    
    # Add game_seconds columns (vectorized using apply)
    logging.info("Converting game times to seconds")
    clips_df['start_seconds'] = clips_df.apply(
        lambda row: convert_time_to_seconds(int(row['PERIOD']), row['STARTTIME']), axis=1
    )
    clips_df['end_seconds'] = clips_df.apply(
        lambda row: convert_time_to_seconds(int(row['PERIOD']), row['ENDTIME']), axis=1
    )
    clips_df['mid_seconds'] = (clips_df['start_seconds'] + clips_df['end_seconds']) / 2
    
    # Create output directory if it doesn't exist
    output_dir = str(year) # year of the season end
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        logging.info(f"Created output directory: {output_dir}")
    
    # Pre-process rotation data to create a more efficient lookup structure
    logging.info("Creating rotation lookup structure")
    rotation_lookup = {}
    
    # Group rotations by game_id and team_id
    for game_id in rotations_df['GAME_ID'].unique():
        game_rotations = rotations_df[rotations_df['GAME_ID'] == game_id]
        rotation_lookup[game_id] = {}
        
        for team_id in game_rotations['TEAM_ID'].unique():
            team_rotations = game_rotations[game_rotations['TEAM_ID'] == team_id]
            rotation_lookup[game_id][team_id] = []
            
            for _, player_row in team_rotations.iterrows():
                rotation_lookup[game_id][team_id].append({
                    'player_id': str(player_row['PERSON_ID']),
                    'in_time': player_row['IN_TIME_SEC'],
                    'out_time': player_row['OUT_TIME_SEC']
                })
    
    # Function to get players on court using the efficient lookup structure
    def get_players_on_court(team_id, time_sec, game_id):
        if game_id not in rotation_lookup or team_id not in rotation_lookup[game_id]:
            return []
        
        on_court = []
        for player_data in rotation_lookup[game_id][team_id]:
            if player_data['in_time'] <= time_sec < player_data['out_time']:
                on_court.append(player_data['player_id'])
        
        if len(on_court) != 5:
   
            logging.warning(f"Found {len(on_court)} players for team {team_id} at time {time_sec} in game {game_id}. Expected 5 players.")
            if len(on_court)>=5:
                    '''
                    for player_data in rotation_lookup[game_id][team_id]:
                        print(player_data)
                    sys.exit()       
                    '''
                    pass      
            
        return on_court
    
    # Process each team in parallel
    teams = clips_df['TEAM_ID'].unique()
    years = clips_df['Year'].unique()
    
    logging.info(f"Processing data for {len(teams)} teams across {len(years)} years")
    
    for team in teams:
        team_abbrev = id_to_abbrev.get(team, team)  # Get team abbreviation or use ID if not found
        team_clips = clips_df[clips_df['TEAM_ID'] == team]
        
        if len(team_clips) == 0:
            logging.info(f"No clips found for {team_abbrev}, skipping")
            continue
        
        logging.info(f"Processing {len(team_clips)} clips for {team_abbrev}")
        
        # Process players on court for all clips at once
        players_on_list = []
        opp_players_on_list = []
        
        # Group by game to minimize lookups
        for game_id, game_clips in team_clips.groupby('GAMEID'):
            if game_id not in rotation_lookup:
                logging.warning(f"Game {game_id} not found in rotation data")
                players_on_list.extend(["GAME_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["GAME_NOT_FOUND"] * len(game_clips))
                continue
            
            game_teams = list(rotation_lookup[game_id].keys())
            if len(game_teams) < 2:
                logging.warning(f"Not enough teams found for game {game_id}")
                players_on_list.extend(["TEAMS_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["TEAMS_NOT_FOUND"] * len(game_clips))
                continue
            
            # Determine the opponent's team ID
            opponent_team_id = None
            for t_id in game_teams:
                if t_id != team:
                    opponent_team_id = t_id
                    break
            
            if opponent_team_id is None:
                logging.warning(f"Opponent team not found for game {game_id}")
                players_on_list.extend(["OPP_TEAM_NOT_FOUND"] * len(game_clips))
                opp_players_on_list.extend(["OPP_TEAM_NOT_FOUND"] * len(game_clips))
                continue
            
            for _, row in game_clips.iterrows():
                try:
                    mid_time = row['mid_seconds']
      
                        #sys.exit()
                    offensive_players = get_players_on_court(team, mid_time, game_id)
                    defensive_players = get_players_on_court(opponent_team_id, mid_time, game_id)
                    players_on_list.append('|'.join(offensive_players))
                    opp_players_on_list.append('|'.join(defensive_players))
                except Exception as e:
                    logging.error(f"Error processing possession: {str(e)}")
                    players_on_list.append("ERROR")
                    opp_players_on_list.append("ERROR")
        
        # Add players_on column
        team_clips['players_on'] = players_on_list
        team_clips['opp_players_on'] = opp_players_on_list
        team_clips['season'] = season
        
        # Save results using team abbreviation
        output_file = f"{output_dir}/{team_abbrev}_{ogyear}_clips_with_players.csv"
        team_clips.to_csv(output_file, index=False)
        
        # Log statistics
        error_count = team_clips[team_clips['players_on'].isin(['ERROR', 'GAME_NOT_FOUND', 'TEAMS_NOT_FOUND', 'OPP_TEAM_NOT_FOUND'])].shape[0]
        success_count = team_clips.shape[0] - error_count
        logging.info(f"Processed {team_clips.shape[0]} clips for {team_abbrev}. "
                     f"Success: {success_count} ({success_count/team_clips.shape[0]*100:.1f}%), "
                     f"Errors: {error_count} ({error_count/team_clips.shape[0]*100:.1f}%)")
    
    logging.info("Processing complete")
    return True

if __name__ == "__main__":
    start_time = datetime.now()
    logging.info(f"Script started at {start_time}")
    
    result = main(year=2020)
    
    end_time = datetime.now()
    execution_time = end_time - start_time
    logging.info(f"Script completed at {end_time}")
    logging.info(f"Total execution time: {execution_time}")
# Out:
# /tmp/ipykernel_4253/3162379513.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_4253/3162379513.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_4253/3162379513.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
# WARNING:root:Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,088 - WARNING - Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,091 - WARNING - Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,094 - WARNING - Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,097 - WARNING - Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,099 - WARNING - Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,101 - WARNING - Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,102 - WARNING - Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,104 - WARNING - Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,106 - WARNING - Found 0 players for team 1610612740 at time 2880.0 in game 22000940. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# 2025-02-22 01:04:00,109 - WARNING - Found 0 players for team 1610612743 at time 2880.0 in game 22000940. Expected 5 players.
# /tmp/ipykernel_4253/3162379513.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_4253/3162379513.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_4253/3162379513.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
# WARNING:root:Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,603 - WARNING - Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,604 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,606 - WARNING - Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,609 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,611 - WARNING - Found 0 players for team 1610612738 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# 2025-02-22 01:04:00,612 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000336. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 2874.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,674 - WARNING - Found 3 players for team 1610612737 at time 2874.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2840.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,676 - WARNING - Found 2 players for team 1610612737 at time 2840.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2840.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,679 - WARNING - Found 2 players for team 1610612737 at time 2840.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2818.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,680 - WARNING - Found 2 players for team 1610612737 at time 2818.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2818.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,682 - WARNING - Found 2 players for team 1610612737 at time 2818.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2793.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,683 - WARNING - Found 2 players for team 1610612737 at time 2793.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2753.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,685 - WARNING - Found 2 players for team 1610612737 at time 2753.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2712.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,687 - WARNING - Found 2 players for team 1610612737 at time 2712.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2712.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,690 - WARNING - Found 2 players for team 1610612737 at time 2712.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,692 - WARNING - Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,694 - WARNING - Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,695 - WARNING - Found 2 players for team 1610612737 at time 2681.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2653.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,698 - WARNING - Found 2 players for team 1610612737 at time 2653.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2618.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,702 - WARNING - Found 2 players for team 1610612737 at time 2618.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2618.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,705 - WARNING - Found 2 players for team 1610612737 at time 2618.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2582.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,707 - WARNING - Found 4 players for team 1610612738 at time 2582.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2582.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,708 - WARNING - Found 2 players for team 1610612737 at time 2582.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,710 - WARNING - Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,712 - WARNING - Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,715 - WARNING - Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,718 - WARNING - Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,724 - WARNING - Found 4 players for team 1610612738 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,727 - WARNING - Found 2 players for team 1610612737 at time 2559.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2530.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,731 - WARNING - Found 4 players for team 1610612738 at time 2530.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2530.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,733 - WARNING - Found 2 players for team 1610612737 at time 2530.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2507.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,737 - WARNING - Found 4 players for team 1610612738 at time 2507.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2507.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,739 - WARNING - Found 2 players for team 1610612737 at time 2507.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2507.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,740 - WARNING - Found 4 players for team 1610612738 at time 2507.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 2507.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,742 - WARNING - Found 2 players for team 1610612737 at time 2507.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,744 - WARNING - Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,746 - WARNING - Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,748 - WARNING - Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,753 - WARNING - Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,755 - WARNING - Found 4 players for team 1610612738 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,756 - WARNING - Found 4 players for team 1610612737 at time 2473.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2449.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,758 - WARNING - Found 4 players for team 1610612738 at time 2449.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2449.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,759 - WARNING - Found 4 players for team 1610612737 at time 2449.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 2449.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,761 - WARNING - Found 4 players for team 1610612738 at time 2449.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2449.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,762 - WARNING - Found 4 players for team 1610612737 at time 2449.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2410.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,765 - WARNING - Found 2 players for team 1610612738 at time 2410.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2410.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,769 - WARNING - Found 4 players for team 1610612737 at time 2410.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,772 - WARNING - Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,775 - WARNING - Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,777 - WARNING - Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,780 - WARNING - Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,783 - WARNING - Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,784 - WARNING - Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,786 - WARNING - Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,788 - WARNING - Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,790 - WARNING - Found 2 players for team 1610612738 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,792 - WARNING - Found 4 players for team 1610612737 at time 2371.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2335.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,793 - WARNING - Found 2 players for team 1610612738 at time 2335.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2335.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,798 - WARNING - Found 4 players for team 1610612737 at time 2335.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,801 - WARNING - Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,802 - WARNING - Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,803 - WARNING - Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,808 - WARNING - Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,810 - WARNING - Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,812 - WARNING - Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,814 - WARNING - Found 2 players for team 1610612738 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,816 - WARNING - Found 4 players for team 1610612737 at time 2311.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,817 - WARNING - Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,819 - WARNING - Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,821 - WARNING - Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,822 - WARNING - Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,826 - WARNING - Found 2 players for team 1610612738 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,828 - WARNING - Found 4 players for team 1610612737 at time 2268.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,830 - WARNING - Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,835 - WARNING - Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,837 - WARNING - Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,839 - WARNING - Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,841 - WARNING - Found 2 players for team 1610612738 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,842 - WARNING - Found 4 players for team 1610612737 at time 2238.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2212.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,844 - WARNING - Found 2 players for team 1610612738 at time 2212.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2212.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,846 - WARNING - Found 4 players for team 1610612737 at time 2212.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,850 - WARNING - Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,851 - WARNING - Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,853 - WARNING - Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,855 - WARNING - Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,856 - WARNING - Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,857 - WARNING - Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,859 - WARNING - Found 2 players for team 1610612738 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,861 - WARNING - Found 4 players for team 1610612737 at time 2172.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2153.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,863 - WARNING - Found 2 players for team 1610612738 at time 2153.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2153.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,864 - WARNING - Found 4 players for team 1610612737 at time 2153.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,866 - WARNING - Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,868 - WARNING - Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,869 - WARNING - Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,871 - WARNING - Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,873 - WARNING - Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,876 - WARNING - Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,877 - WARNING - Found 2 players for team 1610612738 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,879 - WARNING - Found 4 players for team 1610612737 at time 2127.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2104.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,881 - WARNING - Found 2 players for team 1610612738 at time 2104.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2104.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,884 - WARNING - Found 4 players for team 1610612737 at time 2104.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2104.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,886 - WARNING - Found 2 players for team 1610612738 at time 2104.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2104.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,888 - WARNING - Found 4 players for team 1610612737 at time 2104.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2069.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,891 - WARNING - Found 2 players for team 1610612738 at time 2069.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2069.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,893 - WARNING - Found 4 players for team 1610612737 at time 2069.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2069.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,894 - WARNING - Found 2 players for team 1610612738 at time 2069.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2069.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,896 - WARNING - Found 4 players for team 1610612737 at time 2069.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2033.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,898 - WARNING - Found 2 players for team 1610612738 at time 2033.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2033.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,899 - WARNING - Found 4 players for team 1610612737 at time 2033.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2013.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,901 - WARNING - Found 2 players for team 1610612738 at time 2013.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2013.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,903 - WARNING - Found 4 players for team 1610612737 at time 2013.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 2013.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,905 - WARNING - Found 2 players for team 1610612738 at time 2013.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 2013.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,907 - WARNING - Found 4 players for team 1610612737 at time 2013.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,910 - WARNING - Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,911 - WARNING - Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,912 - WARNING - Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,914 - WARNING - Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,916 - WARNING - Found 2 players for team 1610612738 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,917 - WARNING - Found 4 players for team 1610612737 at time 1994.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1974.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,919 - WARNING - Found 4 players for team 1610612738 at time 1974.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1974.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,921 - WARNING - Found 4 players for team 1610612737 at time 1974.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1974.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,923 - WARNING - Found 4 players for team 1610612738 at time 1974.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1974.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,924 - WARNING - Found 4 players for team 1610612737 at time 1974.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1943.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,926 - WARNING - Found 4 players for team 1610612738 at time 1943.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1943.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,927 - WARNING - Found 4 players for team 1610612737 at time 1943.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,929 - WARNING - Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,932 - WARNING - Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,936 - WARNING - Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,938 - WARNING - Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,940 - WARNING - Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,941 - WARNING - Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,944 - WARNING - Found 4 players for team 1610612738 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,945 - WARNING - Found 4 players for team 1610612737 at time 1909.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1883.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,948 - WARNING - Found 4 players for team 1610612738 at time 1883.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1883.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,950 - WARNING - Found 2 players for team 1610612737 at time 1883.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1883.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,951 - WARNING - Found 4 players for team 1610612738 at time 1883.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1883.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,953 - WARNING - Found 2 players for team 1610612737 at time 1883.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1865.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,954 - WARNING - Found 4 players for team 1610612738 at time 1865.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1865.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,955 - WARNING - Found 2 players for team 1610612737 at time 1865.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1842.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,958 - WARNING - Found 4 players for team 1610612738 at time 1842.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1842.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,960 - WARNING - Found 2 players for team 1610612737 at time 1842.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1842.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,961 - WARNING - Found 4 players for team 1610612738 at time 1842.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1842.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,964 - WARNING - Found 2 players for team 1610612737 at time 1842.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,966 - WARNING - Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,967 - WARNING - Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,969 - WARNING - Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,971 - WARNING - Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,973 - WARNING - Found 4 players for team 1610612738 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,975 - WARNING - Found 2 players for team 1610612737 at time 1816.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1782.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,978 - WARNING - Found 4 players for team 1610612738 at time 1782.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1782.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,979 - WARNING - Found 2 players for team 1610612737 at time 1782.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 4 players for team 1610612738 at time 1782.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,981 - WARNING - Found 4 players for team 1610612738 at time 1782.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1782.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,982 - WARNING - Found 2 players for team 1610612737 at time 1782.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1765.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,986 - WARNING - Found 2 players for team 1610612737 at time 1765.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1765.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,987 - WARNING - Found 2 players for team 1610612737 at time 1765.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,989 - WARNING - Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,992 - WARNING - Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,994 - WARNING - Found 2 players for team 1610612737 at time 1721.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1687.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,996 - WARNING - Found 2 players for team 1610612737 at time 1687.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1659.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:00,998 - WARNING - Found 2 players for team 1610612737 at time 1659.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1659.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,000 - WARNING - Found 2 players for team 1610612737 at time 1659.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1628.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,001 - WARNING - Found 2 players for team 1610612737 at time 1628.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1628.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,004 - WARNING - Found 2 players for team 1610612737 at time 1628.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1605.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,006 - WARNING - Found 2 players for team 1610612737 at time 1605.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1584.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,007 - WARNING - Found 2 players for team 1610612737 at time 1584.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1584.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,009 - WARNING - Found 2 players for team 1610612737 at time 1584.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1550.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,010 - WARNING - Found 2 players for team 1610612737 at time 1550.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1526.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,012 - WARNING - Found 2 players for team 1610612737 at time 1526.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1519.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,013 - WARNING - Found 2 players for team 1610612737 at time 1519.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1519.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,016 - WARNING - Found 2 players for team 1610612737 at time 1519.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1482.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,017 - WARNING - Found 2 players for team 1610612737 at time 1482.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,018 - WARNING - Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,020 - WARNING - Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,021 - WARNING - Found 2 players for team 1610612737 at time 1458.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1437.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,023 - WARNING - Found 3 players for team 1610612737 at time 1437.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1437.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,025 - WARNING - Found 3 players for team 1610612737 at time 1437.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1424.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,027 - WARNING - Found 3 players for team 1610612737 at time 1424.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1407.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,028 - WARNING - Found 3 players for team 1610612737 at time 1407.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1387.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,029 - WARNING - Found 3 players for team 1610612737 at time 1387.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,033 - WARNING - Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,034 - WARNING - Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,036 - WARNING - Found 3 players for team 1610612737 at time 1361.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1345.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,037 - WARNING - Found 2 players for team 1610612737 at time 1345.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1345.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,038 - WARNING - Found 2 players for team 1610612737 at time 1345.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1324.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,039 - WARNING - Found 2 players for team 1610612737 at time 1324.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1302.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,042 - WARNING - Found 2 players for team 1610612737 at time 1302.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1302.5 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,044 - WARNING - Found 2 players for team 1610612737 at time 1302.5 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612738 at time 1273.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,045 - WARNING - Found 3 players for team 1610612738 at time 1273.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1273.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,046 - WARNING - Found 2 players for team 1610612737 at time 1273.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612738 at time 1238.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,048 - WARNING - Found 3 players for team 1610612738 at time 1238.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 2 players for team 1610612737 at time 1238.0 in game 22000451. Expected 5 players.
# 2025-02-22 01:04:01,049 - WARNING - Found 2 players for team 1610612737 at time 1238.0 in game 22000451. Expected 5 players.
# WARNING:root:Found 3 players for team 1610612738 at time 1238.0 in game 22000451. Expected 5 players.
# ...
# WARNING:root:Found 1 players for team 1610612748 at time 403.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,765 - WARNING - Found 1 players for team 1610612748 at time 403.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 403.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,766 - WARNING - Found 1 players for team 1610612758 at time 403.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 403.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,769 - WARNING - Found 1 players for team 1610612748 at time 403.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 384.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,771 - WARNING - Found 1 players for team 1610612758 at time 384.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 384.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,773 - WARNING - Found 1 players for team 1610612748 at time 384.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 384.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,774 - WARNING - Found 1 players for team 1610612758 at time 384.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 384.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,776 - WARNING - Found 1 players for team 1610612748 at time 384.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 364.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,777 - WARNING - Found 1 players for team 1610612758 at time 364.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 364.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,778 - WARNING - Found 1 players for team 1610612748 at time 364.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 364.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,779 - WARNING - Found 1 players for team 1610612758 at time 364.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 364.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,780 - WARNING - Found 1 players for team 1610612748 at time 364.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,782 - WARNING - Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,784 - WARNING - Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,788 - WARNING - Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,789 - WARNING - Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,791 - WARNING - Found 1 players for team 1610612758 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,792 - WARNING - Found 1 players for team 1610612748 at time 328.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 295.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,793 - WARNING - Found 1 players for team 1610612758 at time 295.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 295.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,794 - WARNING - Found 1 players for team 1610612748 at time 295.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 277.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,796 - WARNING - Found 1 players for team 1610612758 at time 277.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 277.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,797 - WARNING - Found 1 players for team 1610612748 at time 277.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,798 - WARNING - Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,802 - WARNING - Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,804 - WARNING - Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,805 - WARNING - Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,807 - WARNING - Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,808 - WARNING - Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,811 - WARNING - Found 1 players for team 1610612758 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,813 - WARNING - Found 1 players for team 1610612748 at time 251.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 223.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,814 - WARNING - Found 1 players for team 1610612758 at time 223.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 223.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,815 - WARNING - Found 1 players for team 1610612748 at time 223.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 193.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,817 - WARNING - Found 1 players for team 1610612758 at time 193.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 193.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,818 - WARNING - Found 1 players for team 1610612748 at time 193.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 193.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,820 - WARNING - Found 1 players for team 1610612758 at time 193.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 193.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,824 - WARNING - Found 1 players for team 1610612748 at time 193.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 160.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,826 - WARNING - Found 1 players for team 1610612758 at time 160.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 160.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,827 - WARNING - Found 1 players for team 1610612748 at time 160.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 123.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,829 - WARNING - Found 1 players for team 1610612758 at time 123.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 123.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,830 - WARNING - Found 1 players for team 1610612748 at time 123.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 108.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,831 - WARNING - Found 1 players for team 1610612758 at time 108.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 108.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,833 - WARNING - Found 1 players for team 1610612748 at time 108.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 108.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,834 - WARNING - Found 1 players for team 1610612758 at time 108.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 108.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,839 - WARNING - Found 1 players for team 1610612748 at time 108.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 71.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,840 - WARNING - Found 1 players for team 1610612758 at time 71.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 71.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,841 - WARNING - Found 1 players for team 1610612748 at time 71.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 71.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,843 - WARNING - Found 1 players for team 1610612758 at time 71.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 71.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,844 - WARNING - Found 1 players for team 1610612748 at time 71.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 40.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,845 - WARNING - Found 1 players for team 1610612758 at time 40.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 40.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,849 - WARNING - Found 1 players for team 1610612748 at time 40.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 40.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,850 - WARNING - Found 1 players for team 1610612758 at time 40.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 40.0 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,852 - WARNING - Found 1 players for team 1610612748 at time 40.0 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612758 at time 11.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,853 - WARNING - Found 1 players for team 1610612758 at time 11.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 1 players for team 1610612748 at time 11.5 in game 22000447. Expected 5 players.
# 2025-02-22 01:04:30,856 - WARNING - Found 1 players for team 1610612748 at time 11.5 in game 22000447. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,147 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,149 - WARNING - Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,151 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,153 - WARNING - Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,155 - WARNING - Found 0 players for team 1610612758 at time 2880.0 in game 22000915. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# 2025-02-22 01:04:31,157 - WARNING - Found 0 players for team 1610612744 at time 2880.0 in game 22000915. Expected 5 players.
# /tmp/ipykernel_4253/3162379513.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_4253/3162379513.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_4253/3162379513.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
# WARNING:root:Found 0 players for team 1610612766 at time 2880.0 in game 22000252. Expected 5 players.
# 2025-02-22 01:04:31,597 - WARNING - Found 0 players for team 1610612766 at time 2880.0 in game 22000252. Expected 5 players.
# WARNING:root:Found 0 players for team 1610612753 at time 2880.0 in game 22000252. Expected 5 players.
# 2025-02-22 01:04:31,600 - WARNING - Found 0 players for team 1610612753 at time 2880.0 in game 22000252. Expected 5 players.
# /tmp/ipykernel_4253/3162379513.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['players_on'] = players_on_list
# /tmp/ipykernel_4253/3162379513.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['opp_players_on'] = opp_players_on_list
# /tmp/ipykernel_4253/3162379513.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_clips['season'] = season
